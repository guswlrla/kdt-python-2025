# %%
a = 3
if(a < 5): # 파이썬은 :랑 탭 중요함
    print("hello!")
# Out:
# hello!

# %%
a = None
if(a):
    print('true')

# %%
a = 0 # false
if (a):
    print('hahaha!')
else:
    print("haha!")
# Out:
# haha!

# %%
a = 3.13
a += 0.01
a == 3.14 # 같다 다르다 비교는 정수만
# Out:
# False

# %%
e = 1e-6
abs(a - 3.14) < e
# Out:
# True

# %%
s1 = 'hello'
s2 = 'hello'

s1 == s2
# Out:
# True

# %%
s1 = str('hello')
s2 = str('hello')

s1 == s2 # 자바에선 객체가 다르기 때문에 False가 나옴
# Out:
# True

# %%
d1 = [1, 2, 3]
d2 = [1, 2, 3]

d1 == d2 # 파이썬은 값을 비교함
# Out:
# True

# %%
id(d1) == id(d2) # 메모리 비교하고 싶으면 id
# Out:
# False

# %%
s = 'hello'
'h' in s # s에 h가 포함되어 있는가

d = [1, 2, 3]
3 in d, 4 in d # in연산자
# Out:
# (True, False)

# %%
a = 5
if(a <  5):
    pass # 단순문
elif a > 5: # else if - 파이썬은 elif
    pass
else:
    pass

# %%
a = 1
b = 3

if a == 1 and b == 2: # 단락평가
    print("안녕")

# %%
b = 'ok' if a < 5 else 'no'
b
# Out:
# 'ok'

# %%
data=[1, 2, 3, 4, 5]
[d for d in data if d%2 == 0]
# Out:
# [2, 4]

# %%
if(a == 1):
    if(b==2):
        print('aaa')
        print('bbb')
    else:
        print('ccc')
else:
    print('aaa')
# Out:
# ccc

# %%
data = [2, 1, 3]
data.sort() # return 안됨, 원봄 바꿈
data
# Out:
# [1, 2, 3]

# %%
data = [2, 1, 3]
sorted(data) # return 됨, 원본 데이터는 바뀌지 않음
sorted(data, reverse=True) # 내림차순
# Out:
# [3, 2, 1]

# %%
data
# Out:
# [1, 2, 3]

# %%
max(2, 1, 3) # 내장 함수
# Out:
# 3

# %%
and = 5 # 함수는 되는데, 예약어는 변수로 못 씀
# Out:
#   Cell In[68], line 1
#     and = 5 # 함수는 되는데, 예약어는 변수로 못 씀
#     ^
# SyntaxError: invalid syntax
